# %% [markdown]
# ## **Prompts in langgraph**

# %%
from langchain_ollama import ChatOllama
from pprint import pprint

# %%
from langchain_core.messages import HumanMessage

llm = ChatOllama(model="mistral:7b", temperature=0.3)

# %%
from langchain_core.prompts import ChatPromptTemplate

my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant that helps to create and curate posts for a social media platform."),
        ("human","I want to create a post about {topic}")
    ]
)

# %% [markdown]
# ### **Chain With Prompts**

# %%
chain = my_prompt | llm

# %%
llm_res = chain.invoke({"topic": "The importance of data privacy in the digital age"})
pprint(llm_res.content)
# Out:
# (' Title: 🔒 Protecting Your Data: A Crucial Aspect in the Digital Age 🔒\n'
#  '\n'
#  "Hello everyone! In today's interconnected world, our digital footprints are "
#  'growing larger by the day. But with this growth comes the need for a '
#  "heightened focus on data privacy. Let's dive into the importance of data "
#  'privacy in the digital age.\n'
#  '\n'
#  '🌐 The Digital Landscape:\n'
#  "In today's digital landscape, our personal information is more accessible "
#  'than ever. From social media accounts to online shopping, our data is being '
#  'collected, stored, and sometimes even shared without our explicit consent.\n'
#  '\n'
#  '🔒 The Importance of Data Privacy:\n'
#  '1. Personal Control: Data privacy ensures that individuals have control over '
#  'their personal information, allowing them to decide who can access and use '
#  'their data.\n'
#  '\n'
#  '2. Preventing Identity Theft: By safeguarding our data, we can protect '
#  'ourselves from identity theft and fraud, which can have devastating '
#  'consequences.\n'
#  '\n'
#  '3. Maintaining Privacy: Data privacy helps maintain our privacy, allowing us '
#  'to live our lives without unwanted intrusions or surveillance.\n'
#  '\n'
#  '4. Trust and Reputation: Companies that prioritize data privacy build trust '
#  'with their customers, which can lead to a stronger reputation and increased '
#  'customer loyalty.\n'
#  '\n'
#  '🛡️ Protecting Your Data:\n'
#  '1. Use strong, unique passwords for each account.\n'
#  '2. Enable two-factor authentication whenever possible.\n'
#  '3. Be cautious about the information you share online.\n'
#  '4. Regularly update your software and apps to ensure they have the latest '
#  'security features.\n'
#  '5. Research the privacy policies of the apps and websites you use.\n'
#  '\n'
#  "💡 Remember: Your data is valuable, and it's essential to protect it. By "
#  'taking simple steps to secure our digital lives, we can ensure our privacy '
#  'and peace of mind in the digital age.\n'
#  '\n'
#  'Stay safe and secure, everyone! 🌐🔒')
