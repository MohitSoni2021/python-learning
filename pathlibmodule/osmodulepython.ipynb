# %%
import os

# %%
os.listdir()
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  'Basics',
#  'credentials.json',
#  'Genai',
#  'main.py',
#  'modules and imports concepts',
#  'Numpy',
#  'pathlibmodule',
#  'Untitled.ipynb']

# %%
os.getcwd()
# Out:
# '/run/media/mohitsoni/New Volume1/1_LEARN/python'

# %%
[file for file in os.listdir()]
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  'Basics',
#  'credentials.json',
#  'Genai',
#  'main.py',
#  'modules and imports concepts',
#  'Numpy',
#  'pathlibmodule',
#  'Untitled.ipynb']

# %%
# list of files with perticular extension;
[file for file in os.listdir() if file.endswith(".py") ]
# Out:
# ['main.py']

# %%
parent = os.getcwd();

anotherpath = "Genai";

newpath = os.path.join(parent, anotherpath);
newpath
# Out:
# '/run/media/mohitsoni/New Volume1/1_LEARN/python/Genai'

# %%
current = os.listdir('./')
current
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  'Basics',
#  'credentials.json',
#  'Genai',
#  'main.py',
#  'modules and imports concepts',
#  'Numpy',
#  'pathlibmodule',
#  'Untitled.ipynb']
