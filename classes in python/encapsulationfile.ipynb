# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient Balance")

    def get_balance(self):
        return self.__balance

    def _direct_update_balance(self, amount):
        self.__balance += amount;
        print(self.__balance);

# %%
account = BankAccount("Mohit", 5000)

account.deposit(1000)
account.withdraw(2000)

print(account.get_balance())
# Out:
# 4000

# %%
account.__balance # unable to access this reason : __ make the variable private;
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 account.__balance # unable to access this reason : __ make the variable private;
#
# AttributeError: 'BankAccount' object has no attribute '__balance'

# %%
account._direct_update_balance(23432) # This is the private function _ denote private and the __ is private;
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 account._direct_update_balance(23432) # This is the private function _ denote private and the __ is private;
#
# AttributeError: 'BankAccount' object has no attribute '_direct_update_balance'
