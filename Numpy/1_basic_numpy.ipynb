# %%
import numpy as np

# %%
arr = np.array([1,2,3,4]) # generally holds single type of data type.
arr
# Out:
# array([1, 2, 3, 4])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr[0] # indexing start from zero.
# Out:
# np.int64(1)

# %%
arr[-1] # reverse indexing ...
# Out:
# np.int64(4)

# %%
print(arr)
# changing the original arr.
arr[1] = 10 # numpy array are volatiles we can change the value of any index.
print(arr)
# Out:
# [1 2 3 4]
# [ 1 10  3  4]

# %%
arr[2]+arr[3]
# Out:
# np.int64(7)
